# %%
import numpy as np
from matplotlib import pyplot as plt
from Bio import Phylo
from Bio.Seq import Seq
import random
import string
from Bio.Phylo.BaseTree import Tree, Clade
from itertools import product

# Root: MRCA (Most Recent Common Ancestor) of all known given present known taxa ("terminal" taxa of "leaves")
# Parent: "parent" node, given an edge
# Child/children: "children" nodes or "child" node, given an edge 
# Ancestor: any node along the chain of parents, starting from a node 
# Descendant: any node belonging to a clade, starting from a node
# Terminal: "leaf" nodes in the tree

seed = 3
random.seed(seed)
np.random.seed(seed)

# Define bases
purines = ["A", "G"]
pyrimidines = ["C", "T"]
bases = purines + pyrimidines
n_bases = len(bases)

def index_to_sequence(idx):
    seq = "".join([bases[i] for i in idx])
    return seq

def sequence_to_index(seq):
    idx = []
    for base in seq:
        idx.append(np.where(np.array(bases) == base)[0][0])
    idx = np.array(idx)
    return idx

def generate_sequence(seq_len, prob=None, return_idx=False):
    if prob is None:
        idx = np.random.randint(0, n_bases, size=seq_len)
    else:
        idx = np.random.choice(len(prob), size=seq_len, p=prob)
    seq = index_to_sequence(idx)

    if return_idx: 
        return seq, idx
    else: 
        return seq

# Generate root sequence
seq_len = 10 # sequence length
root_seq, root_idx = generate_sequence(seq_len, return_idx=True)
print(f"Root DNA sequence: {root_seq}, corresponding to the indices '{root_idx}'")
# Out:
# Root DNA sequence: CAGTAAAGGT, corresponding to the indices '[2 0 1 3 0 0 0 1 1 3]'

# %%
# JUKES-CANTOR MODEL: construct descendant sequence from ancestor sequence

alpha = 0.5 # mutation rate: ~10^-8 mutations per site per year

# Jukes-Cantor rate matrix
Q = (alpha *  np.ones((n_bases, n_bases)) - 4 * alpha * np.diag(np.ones(n_bases))) / 3
eigenvalues, eigenvectors = np.linalg.eig(Q) # Q = S @ L @ S^-1 = eigenvectors @ np.diag(eigenvalues) @ np.linalg.inv(eigenvectors)

def Markov_matrix(alpha, edge_len):
    a = 3 / 4 * (1 - np.exp(-4 / 3 * alpha * edge_len))
    M = (a / 3 *  np.ones((n_bases, n_bases)) + (1 - 4 / 3 * a) * np.diag(np.ones(n_bases)))
    return M

# Check that the Markov matrix as defined by the function corresponds to the one obtained by exponentiating the rate matrix Q
edge_len = 0.3
M = eigenvectors @ np.diag(np.exp(eigenvalues * edge_len)) @ np.linalg.inv(eigenvectors)
assert np.allclose(M, Markov_matrix(alpha, edge_len))

def Markov_process(p_init, transition_matrix):
    p_final = p_init @ transition_matrix
    return p_final

# Check that the descendant probability distribution is the same as the root distribution
p_root = np.ones(n_bases) / n_bases # equal probability
M = Markov_matrix(alpha, edge_len)
p_desc = Markov_process(p_root, M)
assert np.all(p_desc == p_root)

# %%
from keras.utils import to_categorical

def one_hot_encoding(idx): 
    one_hot_enc = to_categorical(idx, num_classes=n_bases)
    return one_hot_enc

def generate_child_from_parent(parent, alpha, edge_len, return_idx=False): # can accept either sequence or indices
    seq_len = len(parent)

    if type(parent) == str:
        parent_idx = sequence_to_index(parent)
    else:
        parent_idx = parent
    parent_prob = one_hot_encoding(parent_idx)
    M = Markov_matrix(alpha, edge_len)
    child_prob = Markov_process(parent_prob, M)
    child_seq = "".join([generate_sequence(1, prob=child_prob[i])[0] for i in range(seq_len)])
    
    if return_idx:
        child_idx = sequence_to_index(child_seq)
        return child_seq, child_idx
    else:
        return child_seq

def count_mutations(parent_seq, child_seq):
    n_mutations = sum(x != y for x, y in zip(parent_seq, child_seq))
    return n_mutations

# Example
alpha = 1
edge_len = 0.2

child_seq = generate_child_from_parent(root_seq, alpha, edge_len)
n_mutations = count_mutations(root_seq, child_seq)
print(f"Root sequence: {root_seq}\nChild sequence: {child_seq}\nNumber of mutations with alpha = {alpha}, edge length = {edge_len}: {n_mutations}")
# Out:
# Root sequence: CAGTAAAGGT
# Child sequence: CAGAAAAGGT
# Number of mutations with alpha = 1, edge length = 0.2: 1

# %%
def generate_random_taxa_names(n_taxa):
    alphabet = string.ascii_uppercase
    n_alphabet = len(alphabet)
    iter = int(np.ceil(np.emath.logn(n_alphabet, n_taxa)))
    keywords = [''.join(i) for i in product(alphabet, repeat=iter)]
    random_taxa_names = random.sample(keywords, k=n_taxa)

    return random_taxa_names

# Example
n_taxa = 27
print(generate_random_taxa_names(n_taxa))
# Out:
# ['JJ', 'XI', 'VL', 'FD', 'OO', 'XU', 'SR', 'YQ', 'WW', 'CP', 'XW', 'AN', 'SM', 'KF', 'VS', 'JF', 'HO', 'SN', 'VH', 'VQ', 'ST', 'PQ', 'ZE', 'FY', 'JD', 'ZA', 'FZ']

# %%
def get_parent_node(node, parents):
        return parents.get(node)

# %%
class Phylogenetic_Tree(Phylo.BaseTree.Tree):
    def __init__(self, seq_len, alpha, root=None, rooted=True): 
        super().__init__(root=root, rooted=rooted)
        self.seq_len = seq_len
        self.alpha = alpha
        self.root.name = "Root"
        self.root.branch_length = 0.5
        self.dict_children()
        self.dict_parents()
        self.n_taxa = len(self.get_terminals())
        self.taxa_names = [node.name for node in self.get_terminals()]
        self.adjust_branch_lengths()

    @classmethod
    def read_from_file(cls, file_path):
        tree = Phylo.read(file_path, "newick")
        instance = cls(seq_len=seq_len, alpha=alpha, root=tree.clade)
        
        return instance
    
    @classmethod
    def generate_random_tree(cls, n_taxa=None, taxa_names=None):
        if taxa_names is None: # generate tree from a random number of randomly named taxa
            if n_taxa is None:
                n_taxa = np.random.randint(1,100)
            taxa_names = generate_random_taxa_names(n_taxa)
        
        else: # generate tree from predefined terminal taxa
            if n_taxa:
                print(f"Parameter n_taxa = {n_taxa} is redundant")
            n_taxa = len(taxa_names)

        tree = Tree().randomized(taxa_names, branch_length=None)
        instance = cls(seq_len=seq_len, alpha=alpha, root=tree.clade)
        return instance

    def dict_children(self): # init
        children = {}
        for clade in self.find_clades(order="level"):
            if clade.is_terminal():
                pass
            else:
                children[clade] = [parent for parent in clade]
        self.children = children

    def dict_parents(self): # init
        parents = {}
        for clade in self.find_clades(order="level"):
            for child in clade:
                parents[child] = clade
        self.parents = parents

    def adjust_branch_lengths(self): # init
        for node in self.find_clades():
            if node != self.root and (node.branch_length == 0 or node.branch_length is None):
                node.branch_length = np.random.randint(1,10) / 10

        self.distances_from_root = [(node.name, self.distance(node)) for node in self.find_clades()]
        present = max(self.distances_from_root, key=lambda x: x[1])[1]

        for terminal_node in self.get_terminals():
            if terminal_node == self.root:
                continue
            parent = get_parent_node(terminal_node, self.parents)
            terminal_node.branch_length = np.round(present - self.distance(parent), decimals=5)

    def generate_sequences_for_whole_tree(self):
        for parent, children in self.children.items():
            if parent == self.root:
                parent.sequence = generate_sequence(self.seq_len)
            for child in children:
                edge_len = child.branch_length
                child.Markov_matrix = Markov_matrix(self.alpha, edge_len) # alpha? needed for likelihood computation
                child.sequence = generate_child_from_parent(parent.sequence, self.alpha, edge_len)
                child.mutations = count_mutations(parent.sequence, child.sequence)
                
    def remove_internal_node_names(self):
        internal_node_names = []
        for node in self.get_nonterminals():
            internal_node_names.append(node.name)
            if node != self.root:
                node.name = None
        self.internal_node_names = internal_node_names

    def attach_internal_node_names(self): 
        for i, node in enumerate(self.get_nonterminals()):
            node.name = self.internal_node_names[i]
        # if internal nodes have no names

    def draw(self, figsize=(12,6), no_internal_names=False):
        _, ax = plt.subplots(figsize=figsize)
        if no_internal_names:
            self.remove_internal_node_names()
        Phylo.draw(self, axes=ax)

# %%
# Generate a tree from file.

seq_len = 10
alpha = 0.1

tree_file = Phylogenetic_Tree(seq_len, alpha).read_from_file("simple_tree.dnd")
tree_file.generate_sequences_for_whole_tree()
print(tree_file)
tree_file.draw()
# Out:
# Phylogenetic_Tree(alpha=0.1, n_taxa=6, rooted=True, seq_len=10)
#     Clade(branch_length=0.5, name='Root', sequence='CTAGTCGACG')
#         Clade(branch_length=0.1, mutations=0, name='J', sequence='CTAGTCGACG')
#             Clade(mutations=0, name='E', sequence='CTAGTCGACG')
#             Clade(mutations=0, name='F', sequence='CTAGTCGACG')
#         Clade(branch_length=0.3, mutations=0, name='K', sequence='CTAGTCGACG')
#             Clade(branch_length=0.8, mutations=0, name='H', sequence='CTAGTCGACG')
#                 Clade(mutations=0, name='A', sequence='CTAGTCGACG')
#                 Clade(mutations=0, name='B', sequence='CTAGTCGACG')
#             Clade(branch_length=0.3, mutations=0, name='I', sequence='CTAGTCGACG')
#                 Clade(mutations=1, name='C', sequence='CTATTCGACG')
#                 Clade(mutations=1, name='D', sequence='CTAGCCGACG')

# %%
# Generate a random tree

seq_len = 25
alpha = 0.1
n_taxa = 32
taxa_names = generate_random_taxa_names(n_taxa)

tree_random = Phylogenetic_Tree(seq_len, alpha).generate_random_tree(taxa_names=taxa_names)
tree_random.generate_sequences_for_whole_tree()
print(tree_random)
tree_random.draw(figsize=(12,10), no_internal_names=True)
# Out:
# Phylogenetic_Tree(alpha=0.1, n_taxa=32, rooted=True, seq_len=25)
#     Clade(branch_length=0.5, name='Root', sequence='GACCACCTAGCTTGTAAAAGACGAG')
#         Clade(branch_length=0.2, mutations=1, name='n0', sequence='GACCACCTAGCTTCTAAAAGACGAG')
#             Clade(branch_length=0.4, mutations=1, name='n00', sequence='GACCACCTAGCTTTTAAAAGACGAG')
#                 Clade(branch_length=0.8, mutations=5, name='n000', sequence='GACCAGCTAGCTTACCAATGACGAG')
#                     Clade(branch_length=0.5, mutations=0, name='n0000', sequence='GACCAGCTAGCTTACCAATGACGAG')
#                         Clade(mutations=6, name='WP', sequence='CCCAATCTACCTTAACAATGACGAG')
#                         Clade(mutations=8, name='KE', sequence='GGCCAGCTCGCTTAAGCATTTCGAA')
#                     Clade(branch_length=0.5, mutations=0, name='n0001', sequence='GACCAGCTAGCTTACCAATGACGAG')
#                         Clade(branch_length=0.8, mutations=4, name='n00010', sequence='GAAGAGCTAGCTTACGATTGACGAG')
#                             Clade(branch_length=0.9, mutations=3, name='n000100', sequence='GAAAAGCTAGCTTACGATTAACCAG')
#                                 Clade(mutations=4, name='UP', sequence='GAAAATTTAGTTTACGATTAGCCAG')
#                                 Clade(mutations=5, name='LW', sequence='TGAAACCTAGCTTACGGTTAACCGG')
#                             Clade(mutations=5, name='GH', sequence='GAAGAGCTTGCTCAGGAGTCACGAG')
#                         Clade(branch_length=0.4, mutations=0, name='n00011', sequence='GACCAGCTAGCTTACCAATGACGAG')
#                             Clade(mutations=5, name='RN', sequence='GACAAGATAGGTTACCATTGAGGAG')
#                             Clade(mutations=6, name='BF', sequence='TACCGGCTAGCTTTCCAAGGAAGTG')
#                 Clade(branch_length=0.9, mutations=2, name='n001', sequence='GACCAGTTAGCTTTTAAAAGACGAG')
#                     Clade(branch_length=0.3, mutations=1, name='n0010', sequence='GACCAGTTAGATTTTAAAAGACGAG')
#                         Clade(branch_length=0.9, mutations=1, name='n00100', sequence='GACCAGTTAGATTTTAAAAGACGAC')
#                             Clade(branch_length=0.5, mutations=0, name='n001000', sequence='GACCAGTTAGATTTTAAAAGACGAC')
#                                 Clade(branch_length=0.6, mutations=2, name='n0010000', sequence='GACTAGTTAGATTCTAAAAGACGAC')
#                                     Clade(branch_length=0.1, mutations=0, name='n00100000', sequence='GACTAGTTAGATTCTAAAAGACGAC')
#                                         Clade(mutations=5, name='WS', sequence='GACTAGGAAGATTCTAGAAGAGGGC')
#                                         Clade(branch_length=0.8, mutations=2, name='n001000001', sequence='GAGTAGTTAGATTCTAAAAGACGTC')
#                                             Clade(mutations=4, name='BK', sequence='AAGTAGTTAGCTTTTAACAGACGTC')
#                                             Clade(mutations=6, name='KP', sequence='GAGTATTTGAATTCTAGAAGACCTG')
#                                     Clade(branch_length=0.6, mutations=0, name='n00100001', sequence='GACTAGTTAGATTCTAAAAGACGAC')
#                                         Clade(branch_length=0.3, mutations=2, name='n001000010', sequence='GAATAGTTAGATTCTAAAAGACGTC')
#                                             Clade(mutations=5, name='YR', sequence='GAAGAGTTAGATTGTGAACGACGGC')
#                                             Clade(mutations=1, name='IO', sequence='GAATAGTTAGGTTCTAAAAGACGTC')
#                                         Clade(branch_length=0.8, mutations=1, name='n001000011', sequence='GACTAGTTATATTCTAAAAGACGAC')
#                                             Clade(mutations=1, name='TZ', sequence='GACTAGTTATATTCTAAAAGGCGAC')
#                                             Clade(mutations=1, name='AP', sequence='GACTAGTTATATTCTAAAAGACGTC')
#                                 Clade(mutations=9, name='XH', sequence='AAGCTATTCGAGTTTAAACAAAGAC')
#                             Clade(branch_length=0.6, mutations=0, name='n001001', sequence='GACCAGTTAGATTTTAAAAGACGAC')
#                                 Clade(mutations=3, name='FH', sequence='GACCAGTTAGATCGTAAAAGACGAG')
#                                 Clade(mutations=8, name='SQ', sequence='CCCCAGATAGCATGGCAAAGACGAC')
#                         Clade(branch_length=0.7, mutations=1, name='n00101', sequence='GACCAGTTAGATTTTAAAAGATGAG')
#                             Clade(mutations=5, name='XL', sequence='CACCAGTTAGGTTGTAATAGATCAG')
#                             Clade(branch_length=0.9, mutations=4, name='n001011', sequence='GACCTCTTTGATCTTAAAAGATGAG')
#                                 Clade(mutations=5, name='PJ', sequence='CAGGTCCGTGATCTTAAAAGATGAG')
#                                 Clade(branch_length=0.4, mutations=0, name='n0010111', sequence='GACCTCTTTGATCTTAAAAGATGAG')
#                                     Clade(mutations=1, name='CN', sequence='GACCTCTTTGAGCTTAAAAGATGAG')
#                                     Clade(mutations=6, name='QP', sequence='GACCGCACTGATCTCAGAAGAGGAG')
#                     Clade(branch_length=0.7, mutations=1, name='n0011', sequence='GACCAGTTAGCTTTTAAAAGGCGAG')
#                         Clade(mutations=7, name='TM', sequence='GACCAGCTAGCTAATGAAATTGGAG')
#                         Clade(mutations=2, name='PO', sequence='GATCAGTTAGCTTGTAAAAGGCGAG')
#             Clade(branch_length=0.5, mutations=2, name='n01', sequence='GACCAGCTAGCTTCTAAAAGCCGAG')
#                 Clade(mutations=13, name='QV', sequence='AGCCTCCAAGACGCTAGCAACGAAG')
#                 Clade(mutations=9, name='OK', sequence='GGCCAGATATGATCCAATAGGCGAT')
#         Clade(branch_length=0.8, mutations=1, name='n1', sequence='GACCACCTAGCTTGTAAAAGACGAA')
#             Clade(branch_length=0.3, mutations=0, name='n10', sequence='GACCACCTAGCTTGTAAAAGACGAA')
#                 Clade(branch_length=0.3, mutations=0, name='n100', sequence='GACCACCTAGCTTGTAAAAGACGAA')
#                     Clade(mutations=8, name='PF', sequence='CACCCTCGACCTTGTAATAGACGGG')
#                     Clade(mutations=9, name='DV', sequence='AGCTACGCAGTGTGTAAAAGACGGC')
#                 Clade(branch_length=0.6, mutations=2, name='n101', sequence='GTCCACCTGGCTTGTAAAAGACGAA')
#                     Clade(mutations=8, name='FJ', sequence='GCTAAAGTGGCTTGAAAATGACGGA')
#                     Clade(branch_length=0.4, mutations=2, name='n1011', sequence='GTCCACCTGGGTTGTAGAAGACGAA')
#                         Clade(mutations=9, name='NV', sequence='GTCCACCTGAGCACGCGAACGTGAA')
#                         Clade(branch_length=0.6, mutations=1, name='n10111', sequence='GTCCACCTGGGTTGTAGAAGACGTA')
#                             Clade(mutations=4, name='PG', sequence='GTCAAGCTGGGTTGTAGAACACGGA')
#                             Clade(mutations=4, name='RE', sequence='CTCGTCCTGCGTTGTAGAAGACGTA')
#             Clade(mutations=6, name='BR', sequence='GACCATTTGTCTTGAAAAGGACGAA')
